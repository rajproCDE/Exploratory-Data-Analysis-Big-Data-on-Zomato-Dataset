# %% [markdown]
# # **BDA PROJECT**
#
#
# 1.   **Title:** Zomato Food Delivery Prediction
# 2.  **En No.:** 12020002001077

# %% [markdown]
# # **Importing Necessary Libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/drive/MyDrive/Colab Notebooks/newzomato - zomato.csv")

# %%
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.shape
# Out:
# (9551, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9551 entries, 0 to 9550
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Restaurant ID         9551 non-null   int64
#  1   Restaurant Name       9551 non-null   object
#  2   Country Code          9551 non-null   int64
#  3   City                  9551 non-null   object
#  4   Address               9551 non-null   object
#  5   Locality              9551 non-null   object
#  6   Locality Verbose      9551 non-null   object
#  7   Longitude             9551 non-null   float64
#  8   Latitude              9551 non-null   float64
#  9   Cuisines              9542 non-null   object
#  10  Average Cost for two  9551 non-null   int64
#  11  Currency              9551 non-null   object
#  12  Has Table booking     9551 non-null   object
#  13  Has Online delivery   9551 non-null   object
#  14  Is delivering now     9551 non-null   object
# ...

# %%
df.describe()
# Out:
#        Restaurant ID  Country Code    Longitude     Latitude  \
# count   9.551000e+03   9551.000000  9551.000000  9551.000000
# mean    9.051128e+06     18.365616    64.126574    25.854381
# std     8.791521e+06     56.750546    41.467058    11.007935
# min     5.300000e+01      1.000000  -157.948486   -41.330428
# 25%     3.019625e+05      1.000000    77.081343    28.478713
# 50%     6.004089e+06      1.000000    77.191964    28.570469
# 75%     1.835229e+07      1.000000    77.282006    28.642758
# max     1.850065e+07    216.000000   174.832089    55.976980
#
#        Average Cost for two  Price range  Aggregate rating         Votes
# count           9551.000000  9551.000000       9551.000000   9551.000000
# mean            1199.210763     1.804837          2.666370    156.909748
# std            16121.183073     0.905609          1.516378    430.169145
# min                0.000000     1.000000          0.000000      0.000000
# ...

# %%
df.describe(include='O')
# Out:
#         Restaurant Name       City                     Address  \
# count              9551       9551                        9551
# unique             7446        141                        8918
# top     Cafe Coffee Day  New Delhi  Dilli Haat, INA, New Delhi
# freq                 83       5473                          11
#
#                Locality            Locality Verbose      Cuisines  \
# count              9551                        9551          9542
# unique             1208                        1265          1825
# top     Connaught Place  Connaught Place, New Delhi  North Indian
# freq                122                         122           936
#
#                   Currency Has Table booking Has Online delivery  \
# count                 9551              9551                9551
# unique                  12                 2                   2
# top     Indian Rupees(Rs.)                No                  No
# ...

# %%
df.nunique()
# Out:
# Restaurant ID           9551
# Restaurant Name         7446
# Country Code              15
# City                     141
# Address                 8918
# Locality                1208
# Locality Verbose        1265
# Longitude               8120
# Latitude                8677
# Cuisines                1825
# Average Cost for two     140
# Currency                  12
# Has Table booking          2
# Has Online delivery        2
# Is delivering now          2
# Switch to order menu       1
# Price range                4
# Aggregate rating          33
# Rating color               6
# Rating text                6
# Votes                   1012
# dtype: int64

# %% [markdown]
# # **1. What are the Available Cuisines Across all Restaurants Listed in Zomato?**

# %%
from pprint import pprint

cuisines_total = df['Cuisines']
texts = []
hash_map = set()
cuisines_total.dropna(inplace=True)
for i in cuisines_total:
    for j in str(i).split(', '):
        if j not in hash_map:
            texts.append(j.lower())
            hash_map.add(j)
pprint(texts)
# Out:
# ['french',
#  'japanese',
#  'desserts',
#  'seafood',
#  'asian',
#  'filipino',
#  'indian',
#  'sushi',
#  'korean',
#  'chinese',
#  'european',
#  'mexican',
#  'american',
#  'ice cream',
#  'cafe',
#  'italian',
#  'pizza',
#  'bakery',
#  'mediterranean',
#  'fast food',
#  'brazilian',
#  'arabian',
#  'bar food',
#  'grill',
#  'international',
#  'peruvian',
#  'latin american',
#  'burger',
#  'juices',
#  'healthy food',
#  'beverages',
#  'lebanese',
#  'sandwich',
#  'steak',
#  'bbq',
#  'gourmet fast food',
#  'mineira',
#  'north eastern',
#  'coffee and tea',
#  'vegetarian',
#  'tapas',
#  'breakfast',
#  'diner',
#  'southern',
#  'southwestern',
#  'spanish',
#  'argentine',
#  'caribbean',
#  'german',
#  'vietnamese',
#  'thai',
#  'modern australian',
#  'teriyaki',
#  'cajun',
#  'canadian',
#  'tex-mex',
#  'middle eastern',
#  'greek',
#  'bubble tea',
#  'tea',
#  'australian',
#  'fusion',
#  'cuban',
#  'hawaiian',
#  'salad',
#  'irish',
# ...

# %% [markdown]
# # **2. Let's see how ratings are distributed?**
#
# > If people are passionately disliking the restaurants on the app there is a good chance they will leave a negative rating. therefore let's see how well the restaurants are faring based on ratings.
#
#
#
# > First we need to filter out ratings outside of India and separate the columns representing ratings. The country code of India is given to be 1.

# %%
ratingdf = df.loc[df['Country Code'] == 1].groupby(['Aggregate rating', 'Rating color', 'Rating text']).size().reset_index()
ratingdf
# Out:
#     Aggregate rating Rating color Rating text     0
# 0                0.0        White   Not rated  2139
# 1                1.8          Red        Poor     1
# 2                1.9          Red        Poor     2
# 3                2.0          Red        Poor     7
# 4                2.1          Red        Poor    15
# 5                2.2          Red        Poor    26
# 6                2.3          Red        Poor    46
# 7                2.4          Red        Poor    83
# 8                2.5       Orange     Average   109
# 9                2.6       Orange     Average   190
# 10               2.7       Orange     Average   250
# 11               2.8       Orange     Average   314
# 12               2.9       Orange     Average   380
# 13               3.0       Orange     Average   465
# 14               3.1       Orange     Average   511
# 15               3.2       Orange     Average   510
# 16               3.3       Orange     Average   472
# ...

# %%
ratingdf.rename(columns={0:'Count'}, inplace=True)
ratingdf
# Out:
#     Aggregate rating Rating color Rating text  Count
# 0                0.0        White   Not rated   2139
# 1                1.8          Red        Poor      1
# 2                1.9          Red        Poor      2
# 3                2.0          Red        Poor      7
# 4                2.1          Red        Poor     15
# 5                2.2          Red        Poor     26
# 6                2.3          Red        Poor     46
# 7                2.4          Red        Poor     83
# 8                2.5       Orange     Average    109
# 9                2.6       Orange     Average    190
# 10               2.7       Orange     Average    250
# 11               2.8       Orange     Average    314
# 12               2.9       Orange     Average    380
# 13               3.0       Orange     Average    465
# 14               3.1       Orange     Average    511
# 15               3.2       Orange     Average    510
# 16               3.3       Orange     Average    472
# ...

# %%
col = ['white', 'red', 'orange', 'yellow', 'green', 'darkgreen']
sns.set_style('darkgrid')
sns.barplot(x='Aggregate rating', y='Count', hue='Rating text', data=ratingdf, palette = col)
plt.rcParams['figure.figsize'] = (10, 10)

# %% [markdown]
# # **3. What is the Average Rating of Restaurants in India?**

# %%
meanrat = df.loc[df['Country Code']==1,'Aggregate rating'].mean()
stdrat = df.loc[df['Country Code']==1,'Aggregate rating'].std()
print("The Average Rating in India is=",meanrat)
print("The Standard Deviation in India is=",stdrat)
# Out:
# The Average Rating in India is= 2.52332408691632
# The Standard Deviation in India is= 1.5109859783144406

# %%
temp = ratingdf[['Rating text', 'Count']].groupby(['Rating text']).sum()
temp.drop('Not rated', axis=0, inplace=True)

# %%
plt.pie(temp['Count'], labels = ['Average', 'Excellent', 'Good', 'Poor', 'Very Good'], autopct='%3.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f3482c3f850>,
# ...
#  [Text(-0.22210725228580602, 1.0773431990234354, 'Average'),
#   Text(-0.9843943288914495, -0.49088471685962376, 'Excellent'),
#   Text(-0.17671439835774694, -1.085712679033021, 'Good'),
#   Text(0.8015457124252754, -0.7533422003927948, 'Poor'),
#   Text(1.0392877021863498, -0.36039016646437116, 'Very Good')],
#  [Text(-0.12114941033771236, 0.5876417449218738, '56.47'),
#   Text(-0.5369423612135178, -0.2677553001052493, '1.78'),
#   Text(-0.09638967183149831, -0.5922069158361932, '28.36'),
#   Text(0.43720675223196837, -0.4109139274869789, '2.76'),
#   Text(0.5668842011925544, -0.19657645443511151, '10.62')])

# %% [markdown]
# # **4. Number of Restaurants in India Providing Online Delivery?**

# %%
hasOnlinedf = df.loc[df['Country Code'] == 1].groupby(['Has Online delivery']).size().reset_index()
hasOnlinedf
# Out:
#   Has Online delivery     0
# 0                  No  6229
# 1                 Yes  2423

# %%
hasOnlinedf.rename(columns={0:'Count'}, inplace=True)
hasOnlinedf
# Out:
#   Has Online delivery  Count
# 0                  No   6229
# 1                 Yes   2423

# %% [markdown]
# # **5. Number of Restaunrants in India Providing Table Booking Functionality**

# %%
hastablebook = df.loc[df['Country Code'] == 1].groupby(['Has Table booking']).size().reset_index()
hastablebook
# Out:
#   Has Table booking     0
# 0                No  7541
# 1               Yes  1111

# %% [markdown]
# # **6. Number of Restaurants in Jaipur Having Online Delivery?**

# %%
jairesto = df.loc[df['City']=='Jaipur'].groupby(['Has Online delivery']).size().reset_index()
jairesto.rename(columns={0:'Count'}, inplace=True)
jairesto
# Out:
#   Has Online delivery  Count
# 0                  No     10
# 1                 Yes     10

# %% [markdown]
# # **7. What is the Average Cost for Two Person in India and United States?**

# %%
averageCostInd=df.loc[df['Country Code']==1,'Average Cost for two'].mean()
print("The Average Cost for two persons in India is=",averageCostInd)
averageCostUS=df.loc[df['Country Code']==216,'Average Cost for two'].mean()
print("the Average Cost for two Persons in the US is= $",averageCostUS)
print("Converting USD to INR for better Data Analysis=",averageCostUS*81.1)
# Out:
# The Average Cost for two persons in India is= 623.370319001387
# the Average Cost for two Persons in the US is= $ 26.152073732718893
# Converting USD to INR for better Data Analysis= 2120.9331797235022

# %% [markdown]
# **Conclusion**
#
# The range of ratings for categories are as follows
# 1.   1.8 - 2.4: poor
# 2.   2.5 - 3.4: Average
# 3.   3.5 - 3.9: Good
# 4.   4.0 - 4.4: Very Good
# 5.   4.4 - 4.9: Excellent
#
#
# The mean rating is 3.24 and 95% of the values lie between 2.15 and 4.34.
#
#
# **Due to low number of poor ratings on restaurants it can be concluded that the rumor is unsubstantiated.**

# %% [markdown]
# # **Finding the relationship between different variables and Ratings.**
#
# **We can use Data Analysis to check what features are useful to implement in a business to get maximum ratings.**
#
# **Let's start by converting some values into 1 and 0.**

# %%
tt = {'Yes': 1, 'No': 0}
col = ['Has Table booking', 'Has Online delivery', 'Is delivering now', 'Switch to order menu']
for c in col:
    df.replace({c:tt}, inplace=True)

# %%
sumlist = df[col].sum()
sumlist
# Out:
# Has Table booking       1158
# Has Online delivery     2451
# Is delivering now         34
# Switch to order menu       0
# dtype: int64

# %%
sumlist.drop(['Switch to order menu'], inplace=True)

# %%
df.drop('Switch to order menu', axis = 1, inplace=True)
df.head()
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
dfrel = df[['Average Cost for two', 'Has Table booking', 'Has Online delivery', 'Is delivering now', 'Price range', 'Aggregate rating', 'Votes']]
dfrel
# Out:
#       Average Cost for two  Has Table booking  Has Online delivery  \
# 0                     1100                  1                    0
# 1                     1200                  1                    0
# 2                     4000                  1                    0
# 3                     1500                  0                    0
# 4                     1500                  1                    0
# ...                    ...                ...                  ...
# 9546                    80                  0                    0
# 9547                   105                  0                    0
# 9548                   170                  0                    0
# 9549                   120                  0                    0
# 9550                    55                  0                    0
#
#       Is delivering now  Price range  Aggregate rating  Votes
# 0                     0            3               4.8    314
# ...

# %% [markdown]
# # **Now let's visualize what features are offered.**

# %%
plt.pie(sumlist, labels=['Table Booking', 'Has Online delivery', 'Is delivering now'],autopct='%1.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f3481992cd0>,
# ...
#  [Text(0.5956114058674388, 0.924795681867413, 'Table Booking'),
#   Text(-0.6224668470669534, -0.906937166678335, 'Has Online delivery'),
#   Text(1.0995272097325803, -0.03224771399164123, 'Is delivering now')],
#  [Text(0.3248789486549665, 0.5044340082913161, '31.79'),
#   Text(-0.33952737112742915, -0.4946930000063645, '67.28'),
#   Text(0.5997421143995891, -0.017589662177258852, '0.93')])

# %%
dfwozeros = df[df['Aggregate rating'] != 0]

# %% [markdown]
# # **Lets Analyze if Online Delivery Affects in Overall Rating?**
# 0 Represents the Restaurants not having Online Delivery
# 1 Represennts the Rating of the restaurants having Online Delivery.

# %%
sns.boxplot(x=col[0], y='Aggregate rating', data=dfwozeros)

# %%
sns.boxplot(x=col[1], y='Aggregate rating', data=dfwozeros)

# %%
sns.boxplot(x=col[2], y='Aggregate rating', data=dfwozeros)

# %% [markdown]
# **Conclusion**
#
# 1.   We can observe that online booking is a common features in restaurants.
# 2.   We can observe that these features don't provide any appreciable difference to the aggregate ratings.
#
# **Implementing these feature doesn't provide a appreciable difference to the rating of the restaurants but online booking is still a good idea to implement.**
#
# **Let's compare with Price range.**
#
# **Concentration of Price Range.**

# %%
sumlist = dfwozeros['Price range'].value_counts()
sumlist
# Out:
# 1    2744
# 2    2711
# 3    1373
# 4     575
# Name: Price range, dtype: int64

# %%
plt.pie(sumlist, labels=[1, 2, 3, 4], autopct='%1.2f')
# Out:
# ([<matplotlib.patches.Wedge at 0x7f3481eee350>,
# ...
#  [Text(0.43476680570813836, 1.0104344732115695, '1'),
#   Text(-1.0378359224386675, -0.3645498568040867, '2'),
#   Text(0.5274811369208399, -0.9652790530166385, '3'),
#   Text(1.0674143279754933, -0.265756754255891, '4')],
#  [Text(0.23714553038625727, 0.5511460762972197, '37.07'),
#   Text(-0.5660923213301823, -0.1988453764385927, '36.62'),
#   Text(0.2877169837750035, -0.5265158470999846, '18.55'),
#   Text(0.5822259970775417, -0.14495822959412236, '7.77')])

# %%
sns.boxplot(x='Price range', y='Aggregate rating', data=dfwozeros)
